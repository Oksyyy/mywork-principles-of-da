# %% [markdown]
# ## Scatter Plots

# %%
# Plotting
import matplotlib.pyplot as plt

# Data manipulation
import numpy as np

# Machine learning
from sklearn import datasets

# %% [markdown]
# ## Resources
# Scatterplots investigate relationships between two variables
# - x, y arrays required
# - s = size (change size of dots)
# - c = color (color things based on different clases of variables)
# https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.scatter.html
#
# ## Scatter Plot Example
# https://matplotlib.org/stable/gallery/shapes_and_collections/scatter.html

# %% [markdown]
# ## Pairs of features

# %%
# https://scikit-learn.org/stable/modules/generated/sklearn.datasets.load_diabetes.html
diabities = datasets.load_diabetes()

# Show
# 442 patience, 10 things measured for each patient
diabities.data
# Out:
# array([[ 0.03807591,  0.05068012,  0.06169621, ..., -0.00259226,
#          0.01990749, -0.01764613],
#        [-0.00188202, -0.04464164, -0.05147406, ..., -0.03949338,
#         -0.06833155, -0.09220405],
#        [ 0.08529891,  0.05068012,  0.04445121, ..., -0.00259226,
#          0.00286131, -0.02593034],
#        ...,
#        [ 0.04170844,  0.05068012, -0.01590626, ..., -0.01107952,
#         -0.04688253,  0.01549073],
#        [-0.04547248, -0.04464164,  0.03906215, ...,  0.02655962,
#          0.04452873, -0.02593034],
#        [-0.04547248, -0.04464164, -0.0730303 , ..., -0.03949338,
#         -0.00422151,  0.00306441]], shape=(442, 10))

# %%
# Keys
diabities.keys()
# Out:
# dict_keys(['data', 'target', 'frame', 'DESCR', 'feature_names', 'data_filename', 'target_filename', 'data_module'])

# %%
# Feature names
diabities.feature_names
# Out:
# ['age', 'sex', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6']

# %%
# Blood pressure
# First dimention ":" represents all the values from one number to another number
# If you don't put any numbers, it defaults to: from 0 until len(data), i.e. [0:len(data)], exclusive if the last index
# Second dimention is the forth column located at index 3
bp = diabities.data[:,3]

# Show first 10 (not including 10th index)
bp[:10]
# Out:
# array([ 0.02187239, -0.02632753, -0.00567042, -0.03665608,  0.02187239,
#        -0.01944183, -0.01599898,  0.06662945, -0.04009893, -0.03321323])

# %%
# BMI
bmi = diabities.data[:,2]

# Show first 10 (not including index 10)
bmi[:10]
# Out:
# array([ 0.06169621, -0.05147406,  0.04445121, -0.01159501, -0.03638469,
#        -0.04069594, -0.04716281, -0.00189471,  0.06169621,  0.03906215])

# %%
# Show data
diabities.data
# Out:
# array([[ 0.03807591,  0.05068012,  0.06169621, ..., -0.00259226,
#          0.01990749, -0.01764613],
#        [-0.00188202, -0.04464164, -0.05147406, ..., -0.03949338,
#         -0.06833155, -0.09220405],
#        [ 0.08529891,  0.05068012,  0.04445121, ..., -0.00259226,
#          0.00286131, -0.02593034],
#        ...,
#        [ 0.04170844,  0.05068012, -0.01590626, ..., -0.01107952,
#         -0.04688253,  0.01549073],
#        [-0.04547248, -0.04464164,  0.03906215, ...,  0.02655962,
#          0.04452873, -0.02593034],
#        [-0.04547248, -0.04464164, -0.0730303 , ..., -0.03949338,
#         -0.00422151,  0.00306441]], shape=(442, 10))

# %% [markdown]
# ## Relationships

# %%
# Create a ffigure and an axis
fig, ax = plt.subplots()

# Scatter plot
ax.scatter(bmi, bp) # default marker is "o"

# Labels
ax.set_xlabel('BMI')
ax.set_ylabel('Blood presssure')
# Out:
# Text(0, 0.5, 'Blood presssure')

# %% [markdown]
# ## Colours

# %%
# Sex values have been normilised in this dataset
sex = diabities.data[:,1]

# Show first 10
sex[:10]
# Out:
# array([ 0.05068012, -0.04464164,  0.05068012, -0.04464164, -0.04464164,
#        -0.04464164,  0.05068012,  0.05068012,  0.05068012, -0.04464164])

# %%
# Uniques sex values (should be only two in the original dataset)
np.unique(sex)
# Out:
# array([-0.04464164,  0.05068012])

# %%
# Create a ffigure and an axis
fig, ax = plt.subplots()

# Scatter plot
# Change marker
# https://matplotlib.org/stable/api/markers_api.html#module-matplotlib.markers
# "c" is for color. We can set a calar or assign it to a variable for the plot to automatically differentiate colors
ax.scatter(bmi, bp, marker ='.', c = sex)

# Labels
ax.set_xlabel('BMI')
ax.set_ylabel('Blood presssure')
# Out:
# Text(0, 0.5, 'Blood presssure')

# %% [markdown]
# ## Size

# %%
# Ages were also normilised in this dataset
age = diabities.data[:,0]

# Show first 10
age[:10]
# Out:
# array([ 0.03807591, -0.00188202,  0.08529891, -0.08906294,  0.00538306,
#        -0.09269548, -0.04547248,  0.06350368,  0.04170844, -0.07090025])

# %%
# Create a ffigure and an axis
fig, ax = plt.subplots()

# Scatter plot
# Change marker
# https://matplotlib.org/stable/api/markers_api.html#module-matplotlib.markers
# "s" is for size. It doesn't really work with this data set due to the fact they normalised the age
# The use of "s" is to show differet dot sizes for different groups
ax.scatter(bmi, bp, marker ='.', s = age)

# Labels
ax.set_xlabel('BMI')
ax.set_ylabel('Blood presssure')
# Out:
# /home/codespace/.local/lib/python3.12/site-packages/matplotlib/collections.py:996: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor
# Text(0, 0.5, 'Blood presssure')
